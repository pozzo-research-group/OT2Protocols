# %% [markdown]
# ### Step 1
# * Open the following link and click on **'Enable the drive API'** while logged in to the google account you want to access the drive from :
# https://developers.google.com/drive/api/v3/quickstart/python?authuser=1

# %% [markdown]
# ### Step 2
# * Click on **'DOWNLOAD CLIENT CONFIGURATION'** and rename the downloaded json file to **'client_secrets.json'**
# * A client_secrets.json file is a JSON formatted file containing the client ID, client secret, and other OAuth 2.0 parameters.
# **Never upload your 'client_secrets.json' to github.**
# * This file has to be in the same folder as the jupyter notebooks you want to access the drive from.

# %% [markdown]
# ### Step 3
# **Install the following packages:**
# * pip install google-api-python-client
# * pip install --upgrade google-api-python-client oauth2client
# * pip install pydrive

# %% [markdown]
# ### Step 4
# **Run the following code to access a folder in your google drive, list all the files and their ID's in the folder, and download a file**

# %% [markdown]
# #### Importing all the necessary packages

# %%
import os
from apiclient import discovery
from httplib2 import Http
import oauth2client
from oauth2client import file, client, tools
import pandas as pd
from googleapiclient.http import MediaIoBaseDownload

import numpy as np

# %% [markdown]
# #### Folder ID
# * The folder ID can be found in the link to the folder.
# * The folder ID has to be specified using both the quotation marks as below
# * Change the folder ID below to that of a folder you want to access in your drive

# %%
folder_id = "'1EzlcvsWzgpDoG3kEndZMq3ac_OKl_WD8'"

# %% [markdown]
# #### Providing authentication to access the google drive.
# * Once you run the following cell, a new tab opens requesting authentication.
# * Select the account you want to access the drive from.
# * Click on **'ALLOW'**
# * Leave the tab which says **'The authentication flow has completed'** until you download the necessary files.

# %%
import pydrive
from pydrive.auth import GoogleAuth as gauth
from pydrive.drive import GoogleDrive

from pydrive.auth import GoogleAuth

#  Creates local webserver and auto handles authentication.
gauth = GoogleAuth()
gauth.LocalWebserverAuth()

#  Create GoogleDrive instance with authenticated GoogleAuth instance
drive = GoogleDrive(gauth)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=161449606473-qgguif5nfi2hc0veq1baj7m8pie3j1ra.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %% [markdown]
# **To get the list of all the files in the specified folder and obtain a dataframe with the file names and their respective id's**

# %%
string = folder_id + ' in parents and trashed=false'

# %%
file_list = drive.ListFile({'q': string}).GetList()
names = []
ids = []
for file1 in file_list:
    names.append(file1['title'])
    ids.append(file1['id'])

# %%
file_names = pd.DataFrame(list(zip(names, ids)), columns = ['names','ids'])
file_names
# Out:
#                                                 names  \
# 0                      SOP_Chemicals_sodiumAzide.docx
# 1            SOP_Chemicals_ChloramineTTrihydrate.docx
# 2                       SOP_Chemicals_NitricAcid.docx
# 3             SOP_Chemicals_NN-dimethylformamide.docx
# 4      SOP_Chemicals_ChromiumChlorideHexahydrate.docx
# 5   SOP_Chemicals_3-mercaptopropylTrimethoxysilane...
# 6             SOP_Chemicals_AmmoniumMetavanadate.docx
# 7                SOP_Chemicals_SodiumBorohydride.docx
# 8     SOP_chemical_4_4-Azobis4-cyanovaleric acid.docx
# 9               Bisphenol A Diglycidyl ether SOP.docx
# 10                        MethylenebisAcrylamide.docx
# 11                             SOP_P-Tolunitrile.docx
# 12                              Ethanolamine SOP.docx
# 13                                2-mthoxyethanol sop
# 14              SOP_chemical_Chlorosulfonic acid.docx
# 15                     Hydrogen Peroxide 30% SOP.docx
# 16                   polyeythyleneimine_solution.docx
# 17                     PEG_Methyl_Ether_Acrylate.docx
# 18                           SOP_Ethylenediamine.docx
# 19  SOP_chemical_Heptadecafluorooctanesulfonic aci...
# 20                           Sodium fluoride SOP.docx
# 21                           Calcium_Hydride_SOP.docx
# 22                   SOP_chemical_Sodium_nitrate.docx
# 23                           SOP Osmium Tetroxide.doc
# 24                                    Pyrene SOP.docx
# 25                                Brilliant_Blue.docx
# 26                             SOP_Iodoacetamide.docx
# 27                methyl viologin dichloride sop.docx
# 28                       Gluteraldehyde_Solution.docx
# 29                             Tripsin_Inhibitor.docx
# 30           SOP_chemical_Sodium_dodecyl_sulfate.docx
# 31                                 SOP_Ferrocene.docx
# 32         SOP_chemical_Gold chloride trihydrate.docx
# 33  Poly(vinylidene chloride-co-vinyl chloride) SO...
# 34                             Potassium Sulphate SOP
# 35                           Ethylene glycol sop.docx
# 36                               SOP_Fluorescein.docx
# 37                   SOP_chemicals_alkane thiols.docx
# 38                        Potassium Sulphate SOP.docx
# 39    Gold nanoparticle cluster and emulsion SOP.docx
# 40            Peroxide Formers SOP Plan and List.docx
# 41               SOP_Cobalt_Chloride_Derivatives.docx
# 42                           2-mthoxyethanol sop.docx
# 43                     Potassium Perchlorate SOP.docx
# 44                             Sulfuric acid sop.docx
# 45               Gold nanoparticle synthesis SOP.docx
# 46                              SOP_Chemicals_Aniline
# 47                         SOP_Chemicals_Aniline.docx
# 48                       SOP_Pyrrole_Derivatives.docx
# 49                        SOP_Chemicals_Methanol.docx
# 50                    SOP_Chemicals_Carbon Black.docx
# 51                    SOP_Chemicals_Persulphates.docx
# 52                                   SOP_Toluene.docx
#
#                                              ids
# 0              1Xaf_W9U0RJtFpQFxs3kJiEexqv7rgVK0
# 1              1pRaRjL-U5RR0n5Hnf_JPo2nc4cqiq7Yo
# 2              1sZyCo2Fs0xiGe-e7y8cgaWLZ6f6QI9wt
# 3              1D9h9aXXoPW7KqrF6wbRk5kjpncf6Waxz
# 4              1oiOeo_rQiV1e4ri5BStbHNPyju4cm5n_
# 5              1-P1Sod_ZEZPbewVqRAal6ihRMZog-G6l
# 6              1UWBMIhpeoGc1Hpm--phQG4O8-8NPZZX1
# 7              1cURc3dcpJNTninXnqqVQl5B42JDLKgwk
# 8              1Glj5XFgD5byZKjV3UCJGOiFBBCkilyxN
# 9              1RSoV3ugpX_HCudNaRh-x05KwkagqOzyW
# 10             1ARHDzh8JnbpmhfTcoeLguVPs9JvC-E2e
# 11             1gLRE3_2YJjBiPYgsxWXnBx0siOYaGGha
# 12             1acZR5k5jhLzWfyJaRcYoW0o9C15Sw4vg
# 13  1dKTohZ55o0sMWz4_aEU5Vxqg9b8L9imz1w_SinLVmvU
# 14             1aE5dY-Pdl527ytJwP3xjbav23FniByiQ
# 15             12VfEUBHTyTx7Em2vqKO8WSZDhwtNbNSK
# 16             12VoFgvyNpHVxMkTDdb7vfixjP0nG50A5
# 17             1MXNSfRmS_pBVTqAs8euG1kfHbiQ3f-7N
# 18             15gU7ovb9_9k_fZ2macAykeVLnlf6al6Z
# 19             1JE7WwDQPVfpz9pBc4_YJL0NTKvwZ_Cim
# 20             14qzBvLELB6gdJJ1XhoAtVVUoE3cqzlOn
# 21             12tlCqesXWj_QZjmRTeVJpA1yTJ1HODx4
# 22             1wSfCCqyqN3qJkxic9fNNQA4jc1MQ4pNB
# 23             1NYAjfl4LKX4Xe5urVF_Sgsf1uPmyy1BV
# 24             14weMY6KSORaL90eosGX5B_ZleYW8E6w6
# 25             1lKU-qfJV8ZZHD3TB0oaz9xFUPpHIAAyp
# 26             1Kwlr2vDsaIoJyh7VxpYOTsI3sB2FbMxK
# 27             1ZYKAzDlQy7sBCdg-NALfaQkPo9GBYG7v
# 28             1WbHa9okrDTeopYLw2JsaNU3XzpDO02jF
# 29             1slqrtGiYP7-VmGcFkVeRN10jthigr_k7
# 30             1q2CC-pMhXya-EhVKWGGOm_FId90VteK9
# 31             1i84Pwc4eFrWXfOFuklshQVdxvFAf-s6h
# 32             1OiBMzpUatu4mAELojvIkt9jkUEiZKG00
# 33             14ix4UpyNjX5gSiSRq2GCpYB1v2o3h7ht
# 34  14G5X3ButLdm02cP_cDklUoFEm4GoLoK3bnn0t9ztrF0
# 35             1uBK2Yqs_bcOCfydiZ1BiVllSyjAXr--Y
# 36             13yTYkydXn00jfzEV7AEIhLS3_RAf15OK
# 37             1KB8FlxHNhhRYkIgk2BKQzGyU42ollRHt
# 38             1VpgoZkIhZTWiYkJNuzYymbrqlKH6AmJK
# 39             19R02kxClwPSybTVP5CePlxYPnY8KCd_n
# 40             1xU5rAbQeWAwcRA_VkbYii8Xv-FZdcz_i
# 41             15wkVhqHTXfQgO-zLOjzaY9uLMIfBCcT0
# 42             1geuE5pQeJwWluIObRZSdd4PRuZ9u0Cbj
# 43             1kVZIMR6EE9x8ZEOXrpb7MbKwY-hLz0TR
# 44             1ddBi3dfBGWYvjr_b6QiFdOXXJ6xmUKUH
# 45             1hmkdr8V3vTiTw1LV_SWjNOl7z9B0Hhbe
# 46  1TlFfjpBG24UcjeVLL0FQ3vPOWnZI5yDba4T6Tya3jhc
# 47             1ar5fzWSGpo5cvwkKBMjkjBSH0PGZ4DS0
# 48             1gNpI4nxNOhuuuRA1rZ5tSRFiIstTgDBe
# 49             1Ns5KT6gYLRVYYzEkNxW2cTZBRTNfX8GT
# 50             1nqUdX4wvede6fOu5D5CLGEGVxtYE1ODS
# 51             1125KJTDPWFZ_H_fGg0DH03ZPLF5UZJiW
# 52             1AnGdPC_1Yne3zWaXCS_K4vsXQTOhGqIL

# %% [markdown]
# ### Downloading a file from google drive to the disk
# **Specifiy the file id of the file you want to download to the disk and specify a new name to save it on the disk**

# %%
file_id = '1AnGdPC_1Yne3zWaXCS_K4vsXQTOhGqIL'
new_file_name = 'SOP_Toluene.docx'
file6 = drive.CreateFile({'id': file_id})
file6.GetContentFile(new_file_name)

# %% [markdown]
# ### Uploading a file from the disk to google drive

# %% [markdown]
# **Title and content type metadata are set automatically based on the provided file path. If you want to provide a different filename, pass it to CreateFile() like this:**
# ##### file1 = drive.CreateFile(metadata={"title": "CustomFileName.txt"})

# %%
# Enter the path to the file you want to upload
file_path = 'jupyter_upload.txt'
file1 = drive.CreateFile()
file1.SetContentFile(file_path)
file1.Upload()
