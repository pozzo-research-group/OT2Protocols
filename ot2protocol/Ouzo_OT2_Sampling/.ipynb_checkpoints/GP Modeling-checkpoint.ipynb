# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
from mpl_toolkits.mplot3d import Axes3D
from itertools import product
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\Edwin\Desktop\test_data\test_df')
data.drop(data.index[0]) # drop dumb header

# pull data
pfh = pd.to_numeric(data['Component 3 wtf'] , errors='coerce')[1:-1].tolist()
ethanol = pd.to_numeric(data['Component 4 wtf'] , errors='coerce')[1:-1].tolist()
absorbance = pd.to_numeric(data['500.0nm'] , errors='coerce')[1:-1].tolist()

# %%
x=ethanol
y=pfh
z=absorbance
# plt.scatter(x,y,c=z)

# %%
x1_training = x #[0,  2,  4,  6,  8, 10, 12, 14, 16,  0,  2,  4,  6,  8, 10, 12, 14, 16]
x2_training = y #[0, 0, 0, 0, 0, 0, 0, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2]
x_training = np.array([[x,y] for x,y in zip(x1_training,x2_training)])
y_observation = z #np.array([-54,-60,-62,-64,-66,-68,-70,-72,-74,-60,-62,-64,-66,-68,-70,-72,-74,-76])

kernal = C(1.0, (1e-1, 1e3)) * RBF(10.0, (1e-3, 1e3))
gp_model = GaussianProcessRegressor(kernel=kernal, n_restarts_optimizer=10, alpha=0.1, normalize_y=True)
gp_model.fit(x_training, y_observation)
# Out:
# GaussianProcessRegressor(alpha=0.1, copy_X_train=True,
#              kernel=1**2 * RBF(length_scale=10), n_restarts_optimizer=10,
#              normalize_y=True, optimizer='fmin_l_bfgs_b',
#              random_state=None)

# %%
# x1_test = np.linspace(0.4, 1) # min to max range of the x1 values,linspace always amkes 50 requal spacing
# x2_test = np.linspace(0, 0.002) # since will only do 50 could somehow increase to be more specfic 
# x_test = (np.array([x1_test, x2_test])).T # ok so same shape as the training # well 50 by 50 is 2500
# y_pred = gp_model.predict(x_test)

# %%
# here is where I am having the most trouble
x1x2 = np.array(list(product(x1_test, x2_test))) # both meshes without using np.meshgrid - dont really understand 100%
y_pred, MSE = gp_model.predict(x1x2, return_std=True) # find the interpolation of the mesh, my issue is that can we contain it, i dont like extrpolation
X0p, X1p = x1x2[:,0].reshape(50,50), x1x2[:,1].reshape(50,50) # grab the seperate meshes 
Zp = np.reshape(y_pred,(50,50))

# %%
# y_pred_of_initial_training = gp_model.predict(x_training)
# y_pred_of_initial_training, y_observation # can compare these two, but should be plotting the obercation

# %%
fig, ax = plt.subplots()
vmin = np.amin(Zp) # not sure 100 about where these vmin should come frm
vmax = np.amax(Zp)
norm=colors.Normalize(vmin=vmin, vmax=vmax)
mappable = ax.pcolormesh(X0p, X1p, Zp, norm = norm)


plt.scatter(x_training[:,0], x_training[:,1], c = y_observation, edgecolors='k') # scatter should be of the training data run through again
plt.xlim([0.3,1])
# Out:
# C:\Users\Edwin\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   """
# (0.3, 1.0)
